# %%
import numpy as np
import pandas as pd
import os

# %%
df1 = pd.read_csv("C:\\Users\\Think\\Desktop\\IS353\\FakeNewsNet\\dataset\\gossipcop_fake.csv", encoding='UTF-8')
df1.head(20)
# Out:
#                       id                                           news_url  \
# 0   gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1   gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2    gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3   gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4   gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
# 5   gossipcop-5189580095  www.townandcountrymag.com/society/tradition/a1...
# 6   gossipcop-9588339534  www.foxnews.com/entertainment/2016/12/16/bigge...
# 7   gossipcop-8753274298  www.eonline.com/news/958257/caitlyn-jenner-add...
# 8   gossipcop-8105333868  www.inquisitr.com/3871816/taylor-swift-reporte...
# 9   gossipcop-2803748870  www.huffingtonpost.com/entry/kate-mckinnon-the...
# 10  gossipcop-7312096991  www.msn.com/en-us/music/celebrity/miley-cyrus-...
# ...

# %%
df2 = pd.read_csv("C:\\Users\\Think\\Desktop\\IS353\\FakeNewsNet\\dataset\\gossipcop_real.csv", encoding='UTF-8')
df2.head(20)
# Out:
#                   id                                           news_url  \
# 0   gossipcop-882573  https://www.brides.com/story/teen-mom-jenelle-...
# 1   gossipcop-875924  https://www.dailymail.co.uk/tvshowbiz/article-...
# 2   gossipcop-894416        https://en.wikipedia.org/wiki/Quinn_Perkins
# 3   gossipcop-857248  https://www.refinery29.com/en-us/2018/03/19192...
# 4   gossipcop-884684  https://www.cnn.com/2017/10/04/entertainment/c...
# 5   gossipcop-899309  https://tech2.org/chris-evans-millie-bobby-bro...
# 6   gossipcop-848092  https://tvline.com/2018/05/02/the-handmaids-ta...
# 7   gossipcop-897293  https://fashionmagazine.com/culture/selena-gom...
# 8   gossipcop-926957  https://decider.com/2018/06/11/claws-season-2-...
# 9   gossipcop-930832  http://www.criticschoice.com/critics-choice-aw...
# 10  gossipcop-918456  https://people.com/tv/scandals-bellamy-young-t...
# 11  gossipcop-912950  http://www.bravotv.com/the-daily-dish/one-of-t...
# ...

# %%
df3 = pd.read_csv("C:\\Users\\Think\\Desktop\\IS353\\FakeNewsNet\\dataset\\politifact_fake.csv", encoding='UTF-8')
df3.head(20)
# Out:
#                  id                                           news_url  \
# 0   politifact15014          speedtalk.com/forum/viewtopic.php?t=51650
# 1   politifact15156  politics2020.info/index.php/2018/03/13/court-o...
# 2   politifact14745  www.nscdscamps.org/blog/category/parenting/467...
# 3   politifact14355  https://howafrica.com/oscar-pistorius-attempts...
# 4   politifact15371  http://washingtonsources.org/trump-votes-for-d...
# 5   politifact14404          gloria.tv/video/yRrtUtTCfPga6cq2VDJPcgQe4
# 6   politifact13919  http://blogs.trendolizer.com/2015/01/new-york-...
# 7   politifact14795  https://web.archive.org/web/20171027105356/htt...
# 8   politifact14328  https://web.archive.org/web/20170702174006/htt...
# 9   politifact13775  http://beforeitsnews.com/opinion-conservative/...
# 10  politifact14678  http://yournewswire.com/youngest-leader-george...
# 11  politifact14394  https://web.archive.org/web/20170731052757/htt...
# ...

# %%
df4 = pd.read_csv("C:\\Users\\Think\\Desktop\\IS353\\FakeNewsNet\\dataset\\politifact_real.csv", encoding='UTF-8')
df4.head(20)
# Out:
#                  id                                           news_url  \
# 0   politifact14984                          http://www.nfib-sbet.org/
# 1   politifact12944  http://www.cq.com/doc/newsmakertranscripts-494...
# 2     politifact333  https://web.archive.org/web/20080204072132/htt...
# 3    politifact4358  https://web.archive.org/web/20110811143753/htt...
# 4     politifact779  https://web.archive.org/web/20070820164107/htt...
# 5   politifact14064  http://www.politifact.com/truth-o-meter/statem...
# 6   politifact14474  https://www.law.cornell.edu/constitution/amend...
# 7    politifact5276  http://americaneedsmitt.com/blog/2011/11/10/mi...
# 8    politifact1313  https://web.archive.org/web/20090913221204/htt...
# 9     politifact937  https://web.archive.org/web/20080623122709/htt...
# 10   politifact8227  http://www.commonwealthfund.org/Publications/I...
# 11   politifact1519  http://www.cbsnews.com/blogs/2010/02/23/politi...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5323 entries, 0 to 5322
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         5323 non-null   object
#  1   news_url   5067 non-null   object
#  2   title      5323 non-null   object
#  3   tweet_ids  5135 non-null   object
# dtypes: object(4)
# memory usage: 166.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16817 entries, 0 to 16816
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         16817 non-null  object
#  1   news_url   16804 non-null  object
#  2   title      16817 non-null  object
#  3   tweet_ids  15759 non-null  object
# dtypes: object(4)
# memory usage: 525.7+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         432 non-null    object
#  1   news_url   428 non-null    object
#  2   title      432 non-null    object
#  3   tweet_ids  392 non-null    object
# dtypes: object(4)
# memory usage: 13.6+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         624 non-null    object
#  1   news_url   567 non-null    object
#  2   title      624 non-null    object
#  3   tweet_ids  409 non-null    object
# dtypes: object(4)
# memory usage: 19.6+ KB

# %%
df1['label'] = 0
df2['label'] = 1
df3['label'] = 0
df4['label'] = 1

# %%
df1.head(10)
# Out:
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4  gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
# 5  gossipcop-5189580095  www.townandcountrymag.com/society/tradition/a1...
# 6  gossipcop-9588339534  www.foxnews.com/entertainment/2016/12/16/bigge...
# 7  gossipcop-8753274298  www.eonline.com/news/958257/caitlyn-jenner-add...
# 8  gossipcop-8105333868  www.inquisitr.com/3871816/taylor-swift-reporte...
# 9  gossipcop-2803748870  www.huffingtonpost.com/entry/kate-mckinnon-the...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# ...

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df.head(10)
# Out:
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4  gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
# 5  gossipcop-5189580095  www.townandcountrymag.com/society/tradition/a1...
# 6  gossipcop-9588339534  www.foxnews.com/entertainment/2016/12/16/bigge...
# 7  gossipcop-8753274298  www.eonline.com/news/958257/caitlyn-jenner-add...
# 8  gossipcop-8105333868  www.inquisitr.com/3871816/taylor-swift-reporte...
# 9  gossipcop-2803748870  www.huffingtonpost.com/entry/kate-mckinnon-the...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23196 entries, 0 to 23195
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         23196 non-null  object
#  1   news_url   22866 non-null  object
#  2   title      23196 non-null  object
#  3   tweet_ids  21695 non-null  object
#  4   label      23196 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 906.2+ KB

# %%
df.to_csv('Fakenewsnet.csv', index=False)
